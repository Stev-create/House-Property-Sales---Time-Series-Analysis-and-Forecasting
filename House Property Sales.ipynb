# %% [markdown]
# # House Property Sales
#
# > Di project ini, saya mencoba menggunakan model ARIMA dan SARIMA untuk melakukan forecasting dengan jangka waktu 1 tahun pada harga properti rumah.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

import statsmodels.api as sm
from pylab import rcParams
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

import warnings
warnings.filterwarnings("ignore")

# %%
sales = pd.read_csv('raw_sales.csv')

# %%
sales.head()
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3
# 3  2007-03-09 00:00:00      2905  380000        house         4
# 4  2007-03-21 00:00:00      2906  310000        house         3

# %%
sales = sales.drop(['postcode','propertyType','bedrooms'], axis = 1)

# %%
sales.head()
# Out:
#               datesold   price
# 0  2007-02-07 00:00:00  525000
# 1  2007-02-27 00:00:00  290000
# 2  2007-03-07 00:00:00  328000
# 3  2007-03-09 00:00:00  380000
# 4  2007-03-21 00:00:00  310000

# %%
def dt(x): # x --> sales['datesold']
    return pd.to_datetime(x)

sales['datesold'] = sales['datesold'].apply(dt)

# %%
df = sales.set_index('datesold')

# %%
df.head()
# Out:
#              price
# datesold
# 2007-02-07  525000
# 2007-02-27  290000
# 2007-03-07  328000
# 2007-03-09  380000
# 2007-03-21  310000

# %%
print('The data Time range from {} to {}'.format(df.index.min(),df.index.max()))
# Out:
# The data Time range from 2007-02-07 00:00:00 to 2019-07-27 00:00:00

# %%
y = df['price'].resample('MS').mean()

# %%
y.head()
# Out:
# datesold
# 2007-02-01    407500.000000
# 2007-03-01    339333.333333
# 2007-04-01    798000.000000
# 2007-05-01    339500.000000
# 2007-06-01    520333.333333
# Freq: MS, Name: price, dtype: float64

# %%
y.isna().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize = (10,5))
sns.boxplot(y = y.values, x = y.index.year)
plt.title('The Trend')
# Out:
# Text(0.5, 1.0, 'The Trend')

# %%
plt.figure(figsize = (10,5))
sns.boxplot(y = y.values, x = y.index.month)
plt.title('The Seasonality')
# Out:
# Text(0.5, 1.0, 'The Seasonality')

# %%
plt.figure(figsize = (12,8))
plt.title('Monthly Average of house Price')
y.plot()

# %% [markdown]
# > Dari plot di atas, sebenarnya sudah dapat dilihat bahwa plot ini tidaklah stationary. Namun untuk memastikannya, saya akan melakukan <i>Dickey Fuller test.</i>

# %% [markdown]
# ## Time series decomposition

# %%
rcParams['figure.figsize'] = 18, 12
decomposition = sm.tsa.seasonal_decompose(y, model='multiplicative')
fig = decomposition.plot()
plt.show()

result = adfuller(y)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-0.6602138026458335
# p-value: 0.8567877254659427

# %% [markdown]
# > Terlihat bahwa time-series ini tidaklah stationary.

# %%
plt.rcParams.update({'figure.figsize':(6,4), 'figure.dpi':120})

ori = y.plot()
ori.set_title('Original Series')
plot_acf(y, title = 'Autocorellation original')

plt.show()

# %% [markdown]
# > Dari plot di atas, terlihat bahwa lag yang besar pun masih memiliki korelasi yang signifikan. Yang mengartikan bahwa time-series ini butuh <i>differencing</i>.

# %% [markdown]
# ## Making a time series Stationary

# %%
diff1 = y.diff().dropna().plot()
diff1.set_title('Time Series Differenced 1')
plot_acf(y.diff(1).dropna(),lags =30,  title = 'Autocorellation Differenced 1')

plt.show()

result = adfuller(y.diff().dropna())
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-5.3037712186114785
# p-value: 5.378016232766266e-06

# %% [markdown]
# Sekarang lebih baik

# %%
y_difference_1 = y.diff().dropna()

# %%
decomposition_difference_1 = sm.tsa.seasonal_decompose(y_difference_1, model='additive') 
fig = decomposition_difference_1.plot()
plt.show()

# %%
y_deseason = y_difference_1/ decomposition_difference_1.seasonal

ori_deseason = y_deseason.plot()
ori_deseason.set_title('Deseason Original')
plot_acf(y_deseason, lags  = 30, title = 'Deseason Autocorellation')
plot_pacf(y_deseason, lags = 30, title = 'Deseason Partial Autocorellation')

plt.show()

result = adfuller(y_deseason)
print('ADF Statistic:{}'.format(result[0]))
print('p-value: {}'.format(result[1]))
# Out:
# ADF Statistic:-20.803589107447092
# p-value: 0.0

# %% [markdown]
# #  ARIMA Model

# %% [markdown]
# ## Manual ARIMA

# %% [markdown]
# Dari plot autocorrelation dan partial autocorrelation di atas terlihat bahwa p = 1, q = 1

# %%
train = y_deseason[:120]
test = y_deseason[120:]

model = ARIMA(train, order=(1, 1, 1))  
fitted = model.fit(disp=-1)  

fc, se, conf = fitted.forecast(29, alpha=0.05)  

fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

print('MAPE : {}'.format(np.mean(np.abs(fc - test)/np.abs(test))))
# Out:
# MAPE : 2.0016398442713426

# %% [markdown]
# ## Auto ARIMA

# %%
train = y_deseason[:120]
test = y_deseason[120:]

model = pm.auto_arima(y_deseason, start_p=1, start_q=1, test='adf', max_p= 4, max_q=4, 
                      m=1, d=None, seasonal=False,   
                      start_P=0, D=0, trace=True,
                      error_action='ignore', 
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())

model.plot_diagnostics(figsize=(7,5))
plt.tight_layout()
plt.show()

fitted, confint = model.predict(n_periods= 29, return_conf_int=True) 
index_of_fc = pd.date_range(train.index[-1], periods = 29, freq='MS')

fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("ARIMA - Final Forecast of House Property Sales")
plt.show()

print('MAPE : {}'.format(np.mean(np.abs(fitted - test)/np.abs(test))))
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,0,1)x(0,0,0,0) [intercept=True]; AIC=981.544, BIC=993.560, Time=0.614 seconds
# Fit ARIMA(0,0,0)x(0,0,0,0) [intercept=True]; AIC=1047.912, BIC=1053.920, Time=0.022 seconds
# Fit ARIMA(1,0,0)x(0,0,0,0) [intercept=True]; AIC=1005.074, BIC=1014.086, Time=0.082 seconds
# Fit ARIMA(0,0,1)x(0,0,0,0) [intercept=True]; AIC=983.897, BIC=992.909, Time=0.160 seconds
# Fit ARIMA(0,0,0)x(0,0,0,0) [intercept=False]; AIC=1047.754, BIC=1050.758, Time=0.017 seconds
# Fit ARIMA(2,0,1)x(0,0,0,0) [intercept=True]; AIC=961.276, BIC=976.296, Time=0.360 seconds
# Fit ARIMA(2,0,0)x(0,0,0,0) [intercept=True]; AIC=960.383, BIC=972.399, Time=0.257 seconds
# Fit ARIMA(3,0,0)x(0,0,0,0) [intercept=True]; AIC=961.485, BIC=976.505, Time=0.365 seconds
# Fit ARIMA(3,0,1)x(0,0,0,0) [intercept=True]; AIC=962.667, BIC=980.690, Time=0.871 seconds
# Total fit time: 2.781 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  149
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                -476.192
# Date:                Sun, 28 Jun 2020   AIC                            960.383
# Time:                        12:47:57   BIC                            972.399
# Sample:                             0   HQIC                           965.265
#                                 - 149
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      2.4106      0.626      3.854      0.000       1.185       3.637
# ar.L1         -0.9033      0.045    -20.012      0.000      -0.992      -0.815
# ar.L2         -0.7123      0.022    -32.049      0.000      -0.756      -0.669
# sigma2        34.5451      2.182     15.830      0.000      30.268      38.822
# ===================================================================================
# Ljung-Box (Q):                       36.32   Jarque-Bera (JB):              1180.33
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                            -2.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# MAPE : 4.167604071097169

# %% [markdown]
# > Performance keduanya masih sama buruknya.

# %% [markdown]
# # SARIMA Model

# %%
train = y[:120]
test = y[120:]

model = pm.auto_arima(y, start_p=0, start_q=0, test='adf', max_p=5, max_q=5, 
                      m=12, d=None, seasonal=True, start_P=0, start_Q = 0, 
                      D=1, trace=True, error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())

model.plot_diagnostics(figsize=(7,5))
plt.show()

fitted, confint = model.predict(n_periods= 30, return_conf_int=True) 
index_of_fc = pd.date_range(train.index[-1], periods = 30, freq='MS')

fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(fitted_series, color='darkgreen', label ='Forecast')
plt.legend()
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast of House Property Sales")
plt.show()

print('MAPE : {}'.format(np.mean(np.abs(fitted - test)/np.abs(test))))
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=3461.282, BIC=3467.122, Time=0.103 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=3358.479, BIC=3370.159, Time=1.025 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=3357.164, BIC=3368.844, Time=0.954 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=3459.901, BIC=3462.821, Time=0.048 seconds
# Fit ARIMA(0,1,1)x(0,1,0,12) [intercept=True]; AIC=3523.370, BIC=3532.130, Time=0.303 seconds
# Fit ARIMA(0,1,1)x(1,1,1,12) [intercept=True]; AIC=3358.810, BIC=3373.410, Time=1.508 seconds
# Fit ARIMA(0,1,1)x(0,1,2,12) [intercept=True]; AIC=3358.537, BIC=3373.137, Time=2.159 seconds
# Fit ARIMA(0,1,1)x(1,1,0,12) [intercept=True]; AIC=3408.260, BIC=3419.940, Time=1.003 seconds
# Fit ARIMA(0,1,1)x(1,1,2,12) [intercept=True]; AIC=3356.160, BIC=3373.680, Time=4.053 seconds
# Fit ARIMA(0,1,1)x(2,1,2,12) [intercept=True]; AIC=3352.420, BIC=3372.860, Time=5.754 seconds
# Fit ARIMA(0,1,1)x(2,1,1,12) [intercept=True]; AIC=3350.619, BIC=3368.139, Time=3.179 seconds
# Fit ARIMA(0,1,1)x(2,1,0,12) [intercept=True]; AIC=3351.671, BIC=3366.271, Time=1.517 seconds
# Fit ARIMA(0,1,0)x(2,1,1,12) [intercept=True]; AIC=3400.331, BIC=3414.931, Time=2.743 seconds
# Fit ARIMA(1,1,1)x(2,1,1,12) [intercept=True]; AIC=3338.560, BIC=3359.000, Time=6.218 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=3343.128, BIC=3360.648, Time=3.341 seconds
# Fit ARIMA(1,1,1)x(2,1,0,12) [intercept=True]; AIC=3340.814, BIC=3358.334, Time=3.344 seconds
# Fit ARIMA(1,1,1)x(2,1,2,12) [intercept=True]; AIC=3340.455, BIC=3363.815, Time=10.712 seconds
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=3384.720, BIC=3399.320, Time=1.506 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=3342.306, BIC=3362.746, Time=8.751 seconds
# Fit ARIMA(1,1,0)x(2,1,1,12) [intercept=True]; AIC=3342.846, BIC=3360.366, Time=3.985 seconds
# Fit ARIMA(2,1,1)x(2,1,1,12) [intercept=True]; AIC=3340.115, BIC=3363.475, Time=11.923 seconds
# Fit ARIMA(1,1,2)x(2,1,1,12) [intercept=True]; AIC=3345.431, BIC=3368.791, Time=5.920 seconds
# Fit ARIMA(0,1,2)x(2,1,1,12) [intercept=True]; AIC=3347.833, BIC=3368.273, Time=4.754 seconds
# Fit ARIMA(2,1,0)x(2,1,1,12) [intercept=True]; AIC=3334.966, BIC=3355.406, Time=5.999 seconds
# Fit ARIMA(2,1,0)x(1,1,1,12) [intercept=True]; AIC=3339.894, BIC=3357.414, Time=3.108 seconds
# Fit ARIMA(2,1,0)x(2,1,0,12) [intercept=True]; AIC=3336.360, BIC=3353.880, Time=2.780 seconds
# Fit ARIMA(2,1,0)x(2,1,2,12) [intercept=True]; AIC=3336.918, BIC=3360.278, Time=9.259 seconds
# Fit ARIMA(2,1,0)x(1,1,0,12) [intercept=True]; AIC=3375.811, BIC=3390.411, Time=2.455 seconds
# Fit ARIMA(2,1,0)x(1,1,2,12) [intercept=True]; AIC=3338.552, BIC=3358.992, Time=6.379 seconds
# Fit ARIMA(3,1,0)x(2,1,1,12) [intercept=True]; AIC=3340.184, BIC=3363.544, Time=5.797 seconds
# Fit ARIMA(3,1,1)x(2,1,1,12) [intercept=True]; AIC=3341.905, BIC=3368.185, Time=18.489 seconds
# Total fit time: 139.134 seconds
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  150
# Model:             SARIMAX(2, 1, 0)x(2, 1, [1], 12)   Log Likelihood               -1660.483
# Date:                              Sun, 28 Jun 2020   AIC                           3334.966
# Time:                                      12:50:19   BIC                           3355.406
# Sample:                                           0   HQIC                          3343.272
#                                               - 150
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    146.8781   2596.804      0.057      0.955   -4942.764    5236.521
# ar.L1         -0.5193      0.049    -10.706      0.000      -0.614      -0.424
# ar.L2         -0.0084      0.042     -0.197      0.844      -0.092       0.075
# ar.S.L12      -0.2833      0.097     -2.925      0.003      -0.473      -0.093
# ar.S.L24      -0.2349      0.044     -5.297      0.000      -0.322      -0.148
# ma.S.L12      -0.3163      0.114     -2.765      0.006      -0.541      -0.092
# sigma2      1.439e+09      0.032    4.5e+10      0.000    1.44e+09    1.44e+09
# ===================================================================================
# Ljung-Box (Q):                       48.38   Jarque-Bera (JB):               269.79
# Prob(Q):                              0.17   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.28   Skew:                            -1.50
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.53e+27. Standard errors may be unstable.
# MAPE : 0.03566936102413011

# %% [markdown]
# * Residual terlihat mengikuti distribusi normal dan tidak memiliki korelasi yang signifikan. Namun seharusnya bisa leibh baik lagi, melihat model di atas masih sedikit bias.
# * MAPE hanya sekitar 4% yang menandakan akurasi yang tinggi. itu kenapa SARIMA akan menjadi model yang tepat untuk dataset ini.

# %% [markdown]
# # Fitting and Prediction
#
# > Forecasting for 1 year prediction

# %%
model.fit(train)
# Out:
# ARIMA(order=(2, 1, 0), seasonal_order=(2, 1, 1, 12), suppress_warnings=True)

# %%
test.tail(1)
# Out:
# datesold
# 2019-07-01    583192.056
# Freq: MS, Name: price, dtype: float64

# %%
year = [
    pd.to_datetime('2019-08-01'),
    pd.to_datetime('2019-09-01'),
    pd.to_datetime('2019-10-01'),
    pd.to_datetime('2019-11-01'),
    pd.to_datetime('2019-12-01'),
    pd.to_datetime('2020-01-01'),
    pd.to_datetime('2020-02-01'),
    pd.to_datetime('2020-03-01'),
    pd.to_datetime('2020-04-01'),
    pd.to_datetime('2020-05-01'),
    pd.to_datetime('2020-06-01'),
    pd.to_datetime('2020-07-01')
]

forecast = model.predict(n_periods = 12)

df_fc = pd.DataFrame({'forecast' : forecast}, index = year)
df_fc
# Out:
#                  forecast
# 2019-08-01  613468.774979
# 2019-09-01  623342.789390
# 2019-10-01  619272.621949
# 2019-11-01  631778.691081
# 2019-12-01  614590.031688
# 2020-01-01  604593.790775
# 2020-02-01  612348.829871
# 2020-03-01  649698.416089
# 2020-04-01  648315.170856
# 2020-05-01  697265.391137
# 2020-06-01  649142.846862
# 2020-07-01  590703.773805

# %%
plt.plot(train, label ='Training')
plt.plot(test, label = 'Actual')
plt.plot(df_fc['forecast'], label = 'forecast')
plt.legend()

# %% [markdown]
# # Conclusion

# %% [markdown]
# SARIMA model yang lebih baik dari ARIMA dalam menangani hal ini. Itu kenapa seasonal faktor tidak dapat dihiraukan pada penjualan properti rumah.
